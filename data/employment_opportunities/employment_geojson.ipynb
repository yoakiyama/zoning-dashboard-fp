# %%
import pandas as pd
import json

# %%
employment_df = pd.read_csv('parsed_employment_data.txt', sep='\t')

# %%
rows_to_duplicate = [0, 1, 6]  # Indices of rows to duplicate
duplicated_rows = employment_df.loc[rows_to_duplicate].copy()

# Step 2: Split the 'NEIGHBORHOOD' column on the slash and expand the DataFrame
split_neighborhoods = duplicated_rows['NEIGHBORHOOD'].str.split('/', expand=True).stack().reset_index(level=1, drop=True)
split_neighborhoods.name = 'NEIGHBORHOOD'  # Rename the series to match the DataFrame column

# Replace the original entries in duplicated_rows with the split entries
duplicated_rows = duplicated_rows.drop(columns='NEIGHBORHOOD').join(split_neighborhoods)
employment_df = employment_df.drop(rows_to_duplicate).reset_index(drop=True)

# Append the modified duplicated rows back to the original DataFrame
employment_df = pd.concat([employment_df, duplicated_rows]).reset_index(drop=True)


# New code to duplicate row 2 and assign new neighborhoods
additional_rows = employment_df.loc[[0]].copy()  # Row to duplicate
new_neighborhoods = ['Downtown', 'Chinatown', 'North End']
new_rows = pd.concat([additional_rows]*len(new_neighborhoods), ignore_index=True)
new_rows['NEIGHBORHOOD'] = new_neighborhoods  # Assign new neighborhood names
employment_df = employment_df.drop([0]).reset_index(drop=True)

employment_df = pd.concat([employment_df, new_rows]).reset_index(drop=True)

# New code to duplicate row 2 and assign new neighborhoods
additional_rows = employment_df.loc[[27]].copy()  # Row to duplicate
new_neighborhoods = ['West End']
new_rows = pd.concat([additional_rows]*len(new_neighborhoods), ignore_index=True)
new_rows['NEIGHBORHOOD'] = new_neighborhoods  # Assign new neighborhood names
employment_df = pd.concat([employment_df, new_rows]).reset_index(drop=True)

additional_rows = employment_df.loc[[28]].copy()  # Row to duplicate
new_neighborhoods = ['Longwood']
new_rows = pd.concat([additional_rows]*len(new_neighborhoods), ignore_index=True)
new_rows['NEIGHBORHOOD'] = new_neighborhoods  # Assign new neighborhood names
employment_df = pd.concat([employment_df, new_rows]).reset_index(drop=True)

additional_rows = employment_df.loc[[4]].copy()  # Row to duplicate
new_neighborhoods = ['Mission Hill']
new_rows = pd.concat([additional_rows]*len(new_neighborhoods), ignore_index=True)
new_rows['NEIGHBORHOOD'] = new_neighborhoods  # Assign new neighborhood names
employment_df = pd.concat([employment_df, new_rows]).reset_index(drop=True)

additional_rows = employment_df.loc[[8]].copy()  # Row to duplicate
new_neighborhoods = ['South Boston Waterfront']
new_rows = pd.concat([additional_rows]*len(new_neighborhoods), ignore_index=True)
new_rows['NEIGHBORHOOD'] = new_neighborhoods  # Assign new neighborhood names
employment_df = pd.concat([employment_df, new_rows]).reset_index(drop=True)

# Set NEIGHBORHOOD as the index
employment_df.set_index('NEIGHBORHOOD', inplace=True)

# %%
employment_df
# Out:
#                          NUM_EST  NUM_EMP   PAY_ANN  PAY_QTR1     POP  \
# NEIGHBORHOOD
# Charlestown                  503    12664    999317    230729   19120
# Dorchester                  1648    23776   1419043    334213  110283
# East Boston                  853    20398   1217494    265088   43066
# Hyde Park                    458     4965    275167     60201   35102
# Jamaica Plain                703    13852    965731    226731   38284
# Mattapan                     242     1899     81688     18476   22734
# Roslindale                   455     5372    250446     55707   30544
# Roxbury                      865    13006    886976    194998   75519
# South Boston                1798    68890  10619740   2950757   43747
# South End                    894    20560   1402286    302364   29073
# West Roxbury                 493     5323    248980     57943   27111
# The Port                    1173    52093   9139616   2335424       0
# ...

# %%
with open("../geographic/Cambridge_Neighborhoods.geojson", "r") as oFile:
    cambridge_json = json.load(oFile)
with open("../geographic/Boston_Neighborhoods.geojson", "r") as oFile:
    boston_json = json.load(oFile)
# Drop keys that are not shared between the two files
boston_json.pop('crs')
boston_json.pop('name')
# Out:
# 'Boston_Neighborhood_Boundaries_approximated_by_2020_Census_Block_Groups'

# %%
neighborhood_set = []
# Iterate through Boston geojson
for feature_d in boston_json['features']:
    neighborhood_set.append(feature_d['properties']['blockgr2020_ctr_neighb_name'])
# Iterate through Cambridge geojson
for feature_d in cambridge_json['features']:
    neighborhood_set.append(feature_d['properties']['NAME'])

boston_json['features'] = [d for d in boston_json['features'] if
                           d['properties']['blockgr2020_ctr_neighb_name']!='Harbor Islands']

neighborhood_set.remove('Harbor Islands')
neighborhood_set
# Out:
# ['Allston',
#  'Back Bay',
#  'Beacon Hill',
#  'Brighton',
#  'Charlestown',
#  'Chinatown',
#  'Dorchester',
#  'Downtown',
#  'East Boston',
#  'Fenway',
#  'Hyde Park',
#  'Jamaica Plain',
#  'Longwood',
#  'Mattapan',
#  'Mission Hill',
#  'North End',
#  'Roslindale',
#  'Roxbury',
#  'South Boston',
#  'South Boston Waterfront',
#  'South End',
#  'West End',
#  'West Roxbury',
#  'The Port',
#  'Neighborhood Nine',
#  'Wellington-Harrington',
#  'Mid-Cambridge',
#  'North Cambridge',
#  'Cambridge Highlands',
#  'Strawberry Hill',
#  'West Cambridge',
#  'Riverside',
#  'Cambridgeport',
#  'Area 2/MIT',
#  'East Cambridge',
#  'Baldwin']

# %%
from copy import deepcopy
# Neighborhoods to include
include_hood_set = neighborhood_set
# Standardize keys for neighborhood in both json dictionaries
std_boston_features_l = []
std_cambridge_features_l = []
for feature_d in boston_json['features']:
    std_feature_d = deepcopy(feature_d)
    std_feature_d.pop('properties')
    properties_d = {}
    neighborhood = feature_d['properties']['blockgr2020_ctr_neighb_name']
    if neighborhood not in include_hood_set:
        continue
    properties_d['neighborhood'] = neighborhood
    if neighborhood in employment_df.index:
        ann_pay_div_emp_value = employment_df.loc[neighborhood, 'ANN_PAY_DIV_EMP']
    else:
        ann_pay_div_emp_value = None
        print(f"No data available for the neighborhood: {neighborhood}")
    properties_d['avg_salary'] = ann_pay_div_emp_value
    #properties_d.update(new_average_dict[neighborhood])
    std_feature_d['properties'] = properties_d
    std_boston_features_l.append(std_feature_d)

for feature_d in cambridge_json['features']:
    std_feature_d = deepcopy(feature_d)
    std_feature_d.pop('properties')
    properties_d = {}
    neighborhood = feature_d['properties']['NAME']
    if neighborhood not in include_hood_set:
        continue
    properties_d['neighborhood'] = neighborhood
    if neighborhood in employment_df.index:
        ann_pay_div_emp_value = employment_df.loc[neighborhood, 'ANN_PAY_DIV_EMP']
    else:
        ann_pay_div_emp_value = None
        print(f"No data available for the neighborhood: {neighborhood}")
    properties_d['avg_salary'] = ann_pay_div_emp_value
    #properties_d.update(new_average_dict[neighborhood])
    std_feature_d['properties'] = properties_d
    std_cambridge_features_l.append(std_feature_d)

# %%
combined_features_l = std_boston_features_l + std_cambridge_features_l
combined_json = {}
combined_json['type'] = 'FeatureCollection'
combined_json['features'] = combined_features_l

# %%
id = 1
for c in combined_json['features']:
    c['id'] = id
    id += 1

# %%
with open("Boston_Cambridge_salary.geojson", 'w') as oFile:
    json.dump(combined_json, oFile)
